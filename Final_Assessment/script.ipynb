-- %% [markdown]
-- # [Final_Assesment]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Final_Assesment]    Script Date: 13-12-2023 11:52:51 ******/
CREATE DATABASE [Final_Assesment]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Final_Assesment', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Final_Assesment.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Final_Assesment_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Final_Assesment_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Final_Assesment] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Final_Assesment].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Final_Assesment] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Final_Assesment] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Final_Assesment] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Final_Assesment] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Final_Assesment] SET ARITHABORT OFF 
GO
ALTER DATABASE [Final_Assesment] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Final_Assesment] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Final_Assesment] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Final_Assesment] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Final_Assesment] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Final_Assesment] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Final_Assesment] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Final_Assesment] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Final_Assesment] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Final_Assesment] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Final_Assesment] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Final_Assesment] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Final_Assesment] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Final_Assesment] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Final_Assesment] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Final_Assesment] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Final_Assesment] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Final_Assesment] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Final_Assesment] SET  MULTI_USER 
GO
ALTER DATABASE [Final_Assesment] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Final_Assesment] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Final_Assesment] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Final_Assesment] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Final_Assesment] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Final_Assesment] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Final_Assesment] SET QUERY_STORE = ON
GO
ALTER DATABASE [Final_Assesment] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Cities]

-- %%
USE [Final_Assesment]
GO

-- %%
/****** Object:  Table [dbo].[Cities]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cities](
	[CityId] [int] NOT NULL,
	[CityName] [nvarchar](100) NULL,
	[StateId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[CityId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Company_Table]

-- %%
/****** Object:  Table [dbo].[Company_Table]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Company_Table](
	[Company_Id] [int] IDENTITY(1,1) NOT NULL,
	[CompanyName] [nvarchar](255) NULL,
	[CompanyEmail] [nvarchar](255) NULL,
	[CompanyURL] [nvarchar](255) NULL,
	[Remark] [nvarchar](max) NULL,
	[CompanyLocation] [nvarchar](255) NULL,
	[UserId] [int] NULL,
	[Phone_Number] [nvarchar](20) NULL,
	[Number_of_Employees] [int] NULL,
	[Timezone] [nvarchar](50) NULL,
	[Country] [nvarchar](100) NULL,
	[State] [nvarchar](100) NULL,
	[City] [nvarchar](100) NULL,
	[CreatedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Company_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Countries]

-- %%
/****** Object:  Table [dbo].[Countries]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Countries](
	[CountryId] [int] NOT NULL,
	[CountryName] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[CountryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[States]

-- %%
/****** Object:  Table [dbo].[States]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[States](
	[StateId] [int] NOT NULL,
	[StateName] [nvarchar](100) NULL,
	[CountryId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[StateId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserTable]

-- %%
/****** Object:  Table [dbo].[UserTable]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserTable](
	[UserId] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](100) NULL,
	[Email] [nvarchar](255) NULL,
	[phone] [nvarchar](20) NULL,
	[encryptedPassword] [nvarchar](255) NULL,
	[decryptedPassword] [nvarchar](255) NULL,
	[CreatedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Cities__StateId__5AEE82B9]

-- %%
ALTER TABLE [dbo].[Cities]  WITH CHECK ADD FOREIGN KEY([StateId])
REFERENCES [dbo].[States] ([StateId])
GO

-- %% [markdown]
-- # [FK__States__CountryI__5812160E]

-- %%
ALTER TABLE [dbo].[States]  WITH CHECK ADD FOREIGN KEY([CountryId])
REFERENCES [dbo].[Countries] ([CountryId])
GO

-- %% [markdown]
-- # [dbo].[GetcityByState]

-- %%
/****** Object:  StoredProcedure [dbo].[GetcityByState]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

	CREATE PROCEDURE [dbo].[GetcityByState]
    @StateId INT = NULL
AS
BEGIN
    IF @StateId  = 0
    BEGIN
        -- Return all states if CountryId is not provided
       select CityId, CityName from Cities 
    END
    ELSE
    BEGIN
        -- Return states based on the specified CountryId
       select CityId, CityName from Cities where StateId=@StateId
    END
END;
  
GO

-- %% [markdown]
-- # [dbo].[GetCompanyDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[GetCompanyDetailsById]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[GetCompanyDetailsById]
  
AS
BEGIN
    SELECT
        Company_Table.*,
        Countries.CountryName,
        States.StateName,
        Cities.CityName
    FROM
        Company_Table
    INNER JOIN
        Countries ON Company_Table.Country = Countries.CountryId
    INNER JOIN
        States ON Company_Table.State = States.StateId
    INNER JOIN
        Cities ON Company_Table.City = Cities.CityId
   
END;
GO

-- %% [markdown]
-- # [dbo].[GetCompanyDetailsByIdByIDiddddddd]

-- %%
/****** Object:  StoredProcedure [dbo].[GetCompanyDetailsByIdByIDiddddddd]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[GetCompanyDetailsByIdByIDiddddddd]
    @CompanyId INT
AS
BEGIN
    SELECT
        Company_Table.*,
        Countries.CountryName,
        States.StateName,
        Cities.CityName
    FROM
        Company_Table
    INNER JOIN
        Countries ON Company_Table.Country = Countries.CountryId
    INNER JOIN
        States ON Company_Table.State = States.StateId
    INNER JOIN
        Cities ON Company_Table.City = Cities.CityId
    WHERE
        Company_Table.Company_Id = @CompanyId;
END;
GO

-- %% [markdown]
-- # [dbo].[GetStatesByCountry]

-- %%
/****** Object:  StoredProcedure [dbo].[GetStatesByCountry]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetStatesByCountry]
    @CountryId INT = NULL
AS
BEGIN
    IF @CountryId =0
    BEGIN
        -- Return all states if CountryId is not provided
        SELECT StateId, StateName
        FROM States;
    END
    ELSE
    BEGIN
        -- Return states based on the specified CountryId
        SELECT StateId, StateName
        FROM States
        WHERE CountryId = @CountryId;
    END
END;
GO

-- %% [markdown]
-- # [dbo].[InsertCompanyTable]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertCompanyTable]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[InsertCompanyTable]
    @CompanyName NVARCHAR(255),
    @CompanyEmail NVARCHAR(255),
    @CompanyURL NVARCHAR(255),
    @Remark NVARCHAR(MAX),
    @CompanyLocation NVARCHAR(255),
    @UserId INT,
    @Phone_Number NVARCHAR(20),
    @Number_of_Employees INT,
    @Timezone NVARCHAR(50),
    @Country NVARCHAR(100),
    @State NVARCHAR(100),
    @City NVARCHAR(100),
	@CreatedAt DATETIME
AS
BEGIN
    INSERT INTO Company_Table (
        CompanyName,
        CompanyEmail,
        CompanyURL,
        Remark,
        CompanyLocation,
        UserId,
        Phone_Number,
        Number_of_Employees,
        Timezone,
        Country,
        State,
        City,
        CreatedAt
    )
    VALUES (
        @CompanyName,
        @CompanyEmail,
        @CompanyURL,
        @Remark,
        @CompanyLocation,
        @UserId,
        @Phone_Number,
        @Number_of_Employees,
        @Timezone,
        @Country,
        @State,
        @City,
		@CreatedAt

       
    );
END;
GO

-- %% [markdown]
-- # [dbo].[sp_Insert_RgisterUserData]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Insert_RgisterUserData]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_Insert_RgisterUserData]
    @Name NVARCHAR(100),
    @Email NVARCHAR(255),
    @Phone NVARCHAR(20),
    @EncryptedPassword NVARCHAR(255),
    @DecryptedPassword NVARCHAR(255),
    @CreatedAt DATETIME
AS
BEGIN
    INSERT INTO UserTable (Name, Email, phone, EncryptedPassword, DecryptedPassword, CreatedAt)
    VALUES (@Name, @Email, @Phone, @EncryptedPassword, @DecryptedPassword, @CreatedAt);
END;
GO

-- %% [markdown]
-- # [dbo].[Sp_UpdateCompanyDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_UpdateCompanyDetailsById]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[Sp_UpdateCompanyDetailsById]
    @Company_Id INT,
    @CompanyName NVARCHAR(255),
    @CompanyEmail NVARCHAR(255),
    @CompanyURL NVARCHAR(255),
    @Remark NVARCHAR(MAX),
    @CompanyLocation NVARCHAR(255),
    @UserId INT,
    @Phone_Number NVARCHAR(20),
    @Number_of_Employees INT,
    @Timezone NVARCHAR(50),
    @Country NVARCHAR(100),
    @State NVARCHAR(100),
    @City NVARCHAR(100)
AS
BEGIN
    UPDATE Company_Table
    SET
        CompanyName = @CompanyName,
        CompanyEmail = @CompanyEmail,
        CompanyURL = @CompanyURL,
        Remark = @Remark,
        CompanyLocation = @CompanyLocation,
        UserId = @UserId,
        Phone_Number = @Phone_Number,
        Number_of_Employees = @Number_of_Employees,
        Timezone = @Timezone,
        Country = @Country,
        State = @State,
        City = @City
    WHERE Company_Id = @Company_Id;
END;
GO

-- %% [markdown]
-- # [dbo].[ValidateLoginUser]

-- %%
/****** Object:  StoredProcedure [dbo].[ValidateLoginUser]    Script Date: 13-12-2023 11:52:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[ValidateLoginUser]
    @Email NVARCHAR(255),
    @DecryptedPassword NVARCHAR(50),
    @Name NVARCHAR(255) OUTPUT
AS
BEGIN
    IF EXISTS (
        SELECT 1
        FROM UserTable
        WHERE Email = @Email
        AND decryptedPassword = @DecryptedPassword
        AND Name = @Name
    )
    BEGIN
        SELECT
            su.UserId,
            su.Name,
            su.Email
        FROM UserTable su
        WHERE su.Email = @Email
            AND su.decryptedPassword = @DecryptedPassword
            AND su.Name = @Name;

        -- Set the @name parameter value
        SET @Name = (SELECT su.Name FROM UserTable su WHERE su.Email = @Email AND su.decryptedPassword = @DecryptedPassword AND su.Name = @Name);
    END
END;
GO

-- %% [markdown]
-- # [Final_Assesment]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Final_Assesment] SET  READ_WRITE 
GO
